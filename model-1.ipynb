# %%
import pandas as pd

# %%
data=pd.read_excel("Data.xlsx")
data
# Out:
#        DES   HBA  HBD   MR     T/K    Dexp  Unnamed: 6  Unnamed: 7  \
# 0     DES2  ChCl   EG  1.2  308.57  1.1163         NaN         NaN
# 1     DES2  ChCl   EG  1.2  312.56  1.1142         NaN         NaN
# 2     DES2  ChCl   EG  1.2  313.52  1.1137         NaN         NaN
# 3     DES2  ChCl   EG  1.2  317.27  1.1116         NaN         NaN
# 4     DES2  ChCl   EG  1.2  319.62  1.1101         NaN         NaN
# ..     ...   ...  ...  ...     ...     ...         ...         ...
# 489  DES45  TBAB  TEG  1.5  336.14  1.0469         NaN         NaN
# 490  DES45  TBAB  TEG  1.5  340.21  1.0441         NaN         NaN
# 491  DES45  TBAB  TEG  1.5  343.16  1.0422         NaN         NaN
# 492  DES45  TBAB  TEG  1.5  349.41  1.0384         NaN         NaN
# 493  DES45  TBAB  TEG  1.5  352.32  1.0370         NaN         NaN
#
#      Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12     MCI  \
# 0           NaN         NaN          NaN          NaN          NaN  1.7208
# 1           NaN         NaN          NaN          NaN          NaN  1.7208
# 2           NaN         NaN          NaN          NaN          NaN  1.7208
# 3           NaN         NaN          NaN          NaN          NaN  1.7208
# 4           NaN         NaN          NaN          NaN          NaN  1.7208
# ..          ...         ...          ...          ...          ...     ...
# 489         NaN         NaN          NaN          NaN          NaN  8.4242
# 490         NaN         NaN          NaN          NaN          NaN  8.4242
# 491         NaN         NaN          NaN          NaN          NaN  8.4242
# 492         NaN         NaN          NaN          NaN          NaN  8.4242
# 493         NaN         NaN          NaN          NaN          NaN  8.4242
#
#      Tbm     Tcm     Vcm    Pcm    ωm        MW
# 0    439  610.73  290.69  59.92  0.94   87.6648
# 1    439  610.73  290.69  59.92  0.94   87.6648
# 2    439  610.73  290.69  59.92  0.94   87.6648
# 3    439  610.73  290.69  59.92  0.94   87.6648
# 4    439  610.73  290.69  59.92  0.94   87.6648
# ..   ...     ...     ...    ...   ...       ...
# 489  579  780.70  702.54  31.24  1.07  177.7200
# 490  579  780.70  702.54  31.24  1.07  177.7200
# 491  579  780.70  702.54  31.24  1.07  177.7200
# 492  579  780.70  702.54  31.24  1.07  177.7200
# 493  579  780.70  702.54  31.24  1.07  177.7200
#
# [494 rows x 20 columns]

# %%
data.dropna(axis=1,inplace=True)
data.columns
# Out:
# Index(['DES', 'HBA', 'HBD', 'MR', 'T/K', 'Dexp', 'MCI', 'Tbm', 'Tcm', 'Vcm',
#        'Pcm', 'ωm', 'MW'],
#       dtype='object')

# %%
data.head()
# Out:
#     DES   HBA HBD   MR     T/K    Dexp     MCI  Tbm     Tcm     Vcm    Pcm  \
# 0  DES2  ChCl  EG  1.2  308.57  1.1163  1.7208  439  610.73  290.69  59.92
# 1  DES2  ChCl  EG  1.2  312.56  1.1142  1.7208  439  610.73  290.69  59.92
# 2  DES2  ChCl  EG  1.2  313.52  1.1137  1.7208  439  610.73  290.69  59.92
# 3  DES2  ChCl  EG  1.2  317.27  1.1116  1.7208  439  610.73  290.69  59.92
# 4  DES2  ChCl  EG  1.2  319.62  1.1101  1.7208  439  610.73  290.69  59.92
#
#      ωm       MW
# 0  0.94  87.6648
# 1  0.94  87.6648
# 2  0.94  87.6648
# 3  0.94  87.6648
# 4  0.94  87.6648

# %%
data.shape
# Out:
# (494, 13)

# %%
from matplotlib import pyplot as plt
temp=data.iloc[:,4]
density=data.iloc[:,5]
plt.scatter(temp,density)
plt.show()

# %%
train=data[['MR','T/K','MCI','ωm','MW']]
Y=data['Dexp']
train.head()
print(train.shape,Y.shape)
# Out:
# (494, 5) (494,)

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler.fit(train)
# Train = scaler.transform(train)

# %%
train
# Out:
#       MR     T/K     MCI    ωm        MW
# 0    1.2  308.57  1.7208  0.94   87.6648
# 1    1.2  312.56  1.7208  0.94   87.6648
# 2    1.2  313.52  1.7208  0.94   87.6648
# 3    1.2  317.27  1.7208  0.94   87.6648
# 4    1.2  319.62  1.7208  0.94   87.6648
# ..   ...     ...     ...   ...       ...
# 489  1.5  336.14  8.4242  1.07  177.7200
# 490  1.5  340.21  8.4242  1.07  177.7200
# 491  1.5  343.16  8.4242  1.07  177.7200
# 492  1.5  349.41  8.4242  1.07  177.7200
# 493  1.5  352.32  8.4242  1.07  177.7200
#
# [494 rows x 5 columns]

# %%
Train=pd.DataFrame(train)
Train.shape
# Out:
# (494, 5)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     Train, Y, test_size=0.3, random_state=42,shuffle=True)

# %%
print(len(X_train),len(X_test),len(y_train),len(y_test))
print(Train.shape,X_test.shape)
# Out:
# 345 149 345 149
# (494, 5) (149, 5)

# %%
# X_val,y_val,X_test,y_test=train_test_split(
# ...     X_test, y_test, test_size=0.1, random_state=42,shuffle=True)

# %%
# print(len(Train))
# print(len(X_val),len(X_test),len(y_val),len(y_test))
# Out:
# 494
# 134 134 15 15

# %%
import tensorflow as tf
import keras
from keras.layers import Dense,Dropout,BatchNormalization
from keras.activations import relu,linear
from keras.models import Sequential
from keras.optimizers import Adam,SGD
from keras.losses import MeanSquaredError
from keras.callbacks import ReduceLROnPlateau

# %%
model=Sequential()
model.add(Dense(256,activation='linear',input_shape=[5]))
model.add(BatchNormalization())
model.add(Dense(128,activation='linear'))
model.add(BatchNormalization())
model.add(Dense(64,activation='linear'))
model.add(BatchNormalization())
model.add(Dense(1,activation='linear'))

# %%
model.summary()
reduceLROnPlateau = ReduceLROnPlateau(monitor='accuracy', 
                                patience=3,
                                verbose=1, 
                                factor=0.5,
                                min_lr=0.00001)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               1536
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 44,545
# Trainable params: 43,649
# Non-trainable params: 896
# _________________________________________________________________

# %%
model.compile(loss='MeanSquaredError',optimizer='adam',metrics=['accuracy'])
#model.fit(X_train,y_train,batch_size=40,epochs=100,callbacks=[ReduceLROnPlateau])

history=model.fit(X_train,y_train, validation_data=[X_test, y_test], epochs=100, callbacks=[reduceLROnPlateau])
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 23ms/step - loss: 1.6655 - accuracy: 0.0000e+00 - val_loss: 256.4142 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.9757 - accuracy: 0.0000e+00 - val_loss: 157.8842 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.7686 - accuracy: 0.0000e+00 - val_loss: 52.7937 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.6524 - accuracy: 0.0000e+00
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5917 - accuracy: 0.0000e+00 - val_loss: 19.1740 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 5/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4745 - accuracy: 0.0000e+00 - val_loss: 11.1875 - val_accuracy: 0.0000e+00 - lr: 5.0000e-04
# Epoch 6/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4079 - accuracy: 0.0000e+00 - val_loss: 4.1327 - val_accuracy: 0.0000e+00 - lr: 5.0000e-04
# Epoch 7/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.3774 - accuracy: 0.0000e+00
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3481 - accuracy: 0.0000e+00 - val_loss: 1.9308 - val_accuracy: 0.0000e+00 - lr: 5.0000e-04
# Epoch 8/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3055 - accuracy: 0.0000e+00 - val_loss: 1.4840 - val_accuracy: 0.0000e+00 - lr: 2.5000e-04
# Epoch 9/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2796 - accuracy: 0.0000e+00 - val_loss: 0.9123 - val_accuracy: 0.0000e+00 - lr: 2.5000e-04
# Epoch 10/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.2649 - accuracy: 0.0000e+00
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2553 - accuracy: 0.0000e+00 - val_loss: 0.3510 - val_accuracy: 0.0000e+00 - lr: 2.5000e-04
# Epoch 11/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.
- val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 62/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1437 - accuracy: 0.0000e+00 - val_loss: 0.1351 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 63/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1428 - accuracy: 0.0000e+00 - val_loss: 0.1330 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 64/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1419 - accuracy: 0.0000e+00 - val_loss: 0.1316 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 65/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1409 - accuracy: 0.0000e+00 - val_loss: 0.1311 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 66/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1400 - accuracy: 0.0000e+00 - val_loss: 0.1314 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 67/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1390 - accuracy: 0.0000e+00 - val_loss: 0.1291 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 68/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1381 - accuracy: 0.0000e+00 - val_loss: 0.1292 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 69/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1374 - accuracy: 0.0000e+00 - val_loss: 0.1278 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 70/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1362 - accuracy: 0.0000e+00 - val_loss: 0.1265 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 71/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1352 - accuracy: 0.0000e+00 - val_loss: 0.1253 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 72/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1343 - accuracy: 0.0000e+00 - val_loss: 0.1254 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 73/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1335 - accuracy: 0.0000e+00 - val_loss: 0.1252 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 74/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1328 - accuracy: 0.0000e+00 - val_loss: 0.1238 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 75/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1318 - accuracy: 0.0000e+00 - val_loss: 0.1220 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 76/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1308 - accuracy: 0.0000e+00 - val_loss: 0.1226 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 77/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1298 - accuracy: 0.0000e+00 - val_loss: 0.1212 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 78/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1291 - accuracy: 0.0000e+00 - val_loss: 0.1201 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 79/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1281 - accuracy: 0.0000e+00 - val_loss: 0.1180 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 80/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1272 - accuracy: 0.0000e+00 - val_loss: 0.1187 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 81/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1264 - accuracy: 0.0000e+00 - val_loss: 0.1159 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 82/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1253 - accuracy: 0.0000e+00 - val_loss: 0.1159 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 83/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1245 - accuracy: 0.0000e+00 - val_loss: 0.1150 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 84/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1236 - accuracy: 0.0000e+00 - val_loss: 0.1151 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 85/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1227 - accuracy: 0.0000e+00 - val_loss: 0.1132 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 86/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1218 - accuracy: 0.0000e+00 - val_loss: 0.1125 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 87/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1208 - accuracy: 0.0000e+00 - val_loss: 0.1115 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 88/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1199 - accuracy: 0.0000e+00 - val_loss: 0.1098 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 89/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1191 - accuracy: 0.0000e+00 - val_loss: 0.1101 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 90/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1183 - accuracy: 0.0000e+00 - val_loss: 0.1103 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 91/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1175 - accuracy: 0.0000e+00 - val_loss: 0.1078 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 92/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1164 - accuracy: 0.0000e+00 - val_loss: 0.1085 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 93/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1157 - accuracy: 0.0000e+00 - val_loss: 0.1062 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 94/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1149 - accuracy: 0.0000e+00 - val_loss: 0.1054 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 95/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1141 - accuracy: 0.0000e+00 - val_loss: 0.1053 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 96/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1132 - accuracy: 0.0000e+00 - val_loss: 0.1042 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 97/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1122 - accuracy: 0.0000e+00 - val_loss: 0.1028 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 98/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1115 - accuracy: 0.0000e+00 - val_loss: 0.1032 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 99/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1108 - accuracy: 0.0000e+00 - val_loss: 0.1008 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 100/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1098 - accuracy: 0.0000e+00 - val_loss: 0.1006 - val_accuracy: 0.0000e+00 - lr: 1.0000e-05

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 345 entries, 16 to 102
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   MR      345 non-null    float64
#  1   T/K     345 non-null    float64
#  2   MCI     345 non-null    float64
#  3   ωm      345 non-null    float64
#  4   MW      345 non-null    float64
# dtypes: float64(5)
# memory usage: 16.2 KB

# %%
from sklearn.metrics import accuracy_score,mean_absolute_error,mean_squared_error
import numpy as np
pred = model.predict(X_test)
pred = np.array(pred)


print(pred.shape)
print(y_test.shape)
print("MAE : ",mean_absolute_error( pred,y_test))
print("MSE : ", mean_squared_error(pred,y_test))
# Out:
# 5/5 [==============================] - 0s 4ms/step
# (149, 1)
# (149,)
# MAE :  0.31582675720970105
# MSE :  0.10446435298811332

# %%
pred=pred.flatten()
print(pred.shape,y_test.shape)
print(len(pred))
print(y_test.shape)
ytest=y_test.to_numpy()
# Out:
# (149,) (149,)
# 149
# (149,)

# %%
# Mape
s=0
for i in range(len(pred)):
    s+=(abs(pred[i]-ytest[i])/ytest[i])
print(s/len(y_test)*100)
# Out:
# 27.489259756409574

# %%
his = pd.DataFrame(history.history['loss'])
his.plot()
# Out:
# <AxesSubplot:>

# %%
# MAPE (hard code)
